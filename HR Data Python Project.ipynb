# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_excel(r'C:\Users\asmaj\Downloads\HR Data.xlsx')

# %%
data
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0          Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1           No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2          Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3           No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4           No      Travel_Rarely     25 - 34  Current Employees        R&D
# ...        ...                ...         ...                ...        ...
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
# ...

# %%
data.isnull()
# Out:
#       Attrition  Business Travel  CF_age band  CF_attrition label  Department  \
# 0         False            False        False               False       False
# 1         False            False        False               False       False
# 2         False            False        False               False       False
# 3         False            False        False               False       False
# 4         False            False        False               False       False
# ...         ...              ...          ...                 ...         ...
# 1465      False            False        False               False       False
# 1466      False            False        False               False       False
# 1467      False            False        False               False       False
# 1468      False            False        False               False       False
# 1469      False            False        False               False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# -2                            0
# 0                             0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# ...

# %%
data.head()
# Out:
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
#    ... Performance Rating Relationship Satisfaction Standard Hours  \
# ...

# %%
data.tail()
# Out:
#      Attrition    Business Travel CF_age band CF_attrition label Department  \
# 1465       Yes         Non-Travel     25 - 34       Ex-Employees        R&D
# 1466       Yes  Travel_Frequently     25 - 34       Ex-Employees        R&D
# 1467       Yes  Travel_Frequently     35 - 44       Ex-Employees      Sales
# 1468       Yes      Travel_Rarely    Under 25       Ex-Employees        R&D
# 1469       Yes      Travel_Rarely    Under 25       Ex-Employees      Sales
#
#        Education Field      emp no  Employee Number Gender  \
# 1465  Technical Degree  STAFF-1905             1905   Male
# 1466     Life Sciences  STAFF-1868             1868   Male
# 1467             Other  STAFF-1667             1667   Male
# 1468     Life Sciences  STAFF-1878             1878   Male
# 1469     Life Sciences  STAFF-1702             1702   Male
#
#                   Job Role  ... Performance Rating Relationship Satisfaction  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Attrition                   1470 non-null   object
#  1   Business Travel             1470 non-null   object
#  2   CF_age band                 1470 non-null   object
#  3   CF_attrition label          1470 non-null   object
#  4   Department                  1470 non-null   object
#  5   Education Field             1470 non-null   object
#  6   emp no                      1470 non-null   object
#  7   Employee Number             1470 non-null   int64
#  8   Gender                      1470 non-null   object
#  9   Job Role                    1470 non-null   object
#  10  Marital Status              1470 non-null   object
#  11  Over Time                   1470 non-null   object
#  12  Over18                      1470 non-null   object
# ...

# %%
data.describe()
# Out:
#        Employee Number  Training Times Last Year      -2       0          Age  \
# count      1470.000000               1470.000000  1470.0  1470.0  1470.000000
# mean       1024.865306                  2.799320    -2.0     0.0    36.923810
# std         602.024335                  1.289271     0.0     0.0     9.135373
# min           1.000000                  0.000000    -2.0     0.0    18.000000
# 25%         491.250000                  2.000000    -2.0     0.0    30.000000
# 50%        1020.500000                  3.000000    -2.0     0.0    36.000000
# 75%        1555.750000                  3.000000    -2.0     0.0    43.000000
# max        2068.000000                  6.000000    -2.0     0.0    60.000000
#
#        CF_current Employee   Daily Rate  Distance From Home  Employee Count  \
# count          1470.000000  1470.000000         1470.000000          1470.0
# mean              0.838776   802.485714            9.192517             1.0
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.bar(data['Monthly Income'],data['Job Role'])
plt.show()

# %%
pd.crosstab(data['Over Time'],data['Department'])
# Out:
# Department  HR  R&D  Sales
# Over Time
# No          46  690    318
# Yes         17  271    128

# %%
sns.barplot(data = data, x = 'Age', y = 'Department',errorbar=('ci', True))
# Out:
# <Axes: xlabel='Age', ylabel='Department'>

# %%
plt.bar(data['Monthly Income'],data['Age'])
plt.grid(color='r',ls='--')
plt.show()

# %%
pd.crosstab(data['Department'],data['Gender']).plot(kind='bar',stacked = True)
plt.text(0,5,20)
plt.text(0,32,40)
plt.text(1,155,379)
plt.text(1,502,582)
plt.text(2,255,189)
plt.text(2,112,257)
plt.show()

# %%
pd.crosstab(data['Gender'],data['Department'])
# Out:
# Department  HR  R&D  Sales
# Gender
# Female      20  379    189
# Male        43  582    257

# %%
pd.crosstab(data['Age'],data['Department'])
# Out:
# Department  HR  R&D  Sales
# Age
# 18           0    5      3
# 19           1    5      3
# 20           0    6      5
# 21           0    7      6
# 22           0   16      0
# 23           0   11      3
# 24           2   17      7
# 25           1   11     14
# 26           3   26     10
# 27           1   33     14
# 28           2   34     12
# 29           3   46     19
# 30           3   37     20
# 31           3   40     26
# 32           0   39     22
# 33           2   35     21
# 34           4   47     26
# 35           2   52     24
# 36           3   44     22
# 37           2   36     12
# 38           4   37     17
# 39           2   30     10
# 40           1   39     17
# 41           3   21     16
# 42           3   35      8
# 43           1   23      8
# 44           4   25      4
# 45           2   27     12
# 46           2   15     16
# 47           1   12     11
# 48           0   13      6
# 49           0   20      4
# 50           1   19     10
# ...

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
sns.stripplot(data=data,x='Age',y='Department')

plt.show()

# %%
sns.violinplot(data=data,x='Years At Company',y='Age')
plt.show()

# %%
sns.barplot(data = data, x = 'Department', y = 'Years At Company',errorbar=('ci', True))
# Out:
# <Axes: xlabel='Department', ylabel='Years At Company'>

# %%
data['Department'].value_counts().plot(kind='pie',autopct='%i%%',explode=[0.1,0,0.2])
plt.show()

# %%
pd.crosstab(data['Marital Status'],data['Department']).plot(kind='bar')
plt.show()

# %%
sns.violinplot(data=data,x='Age',y='Job Role')
plt.show()

# %%
plt.bar(data['Monthly Income'],data['Education'])
plt.show()

# %%
sns.swarmplot(data=data,x='Education',y='Employee Count',hue='Monthly Income')
plt.show()
# Out:
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 95.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 92.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 96.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 97.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
pd.crosstab(data['Over Time'],data['Education'])
# Out:
# Education  Associates Degree  Bachelor's Degree  Doctoral Degree  High School  \
# Over Time
# No                       196                426               34          116
# Yes                       86                146               14           54
#
# Education  Master's Degree
# Over Time
# No                     282
# Yes                    116

# %%
pd.crosstab(data['Monthly Income'],data['Education'])
# Out:
# Education       Associates Degree  Bachelor's Degree  Doctoral Degree  \
# Monthly Income
# 1009                            0                  0                0
# 1051                            1                  0                0
# 1052                            0                  0                0
# 1081                            0                  1                0
# 1091                            0                  1                0
# ...                           ...                ...              ...
# 19859                           0                  1                0
# 19926                           0                  1                0
# 19943                           0                  0                0
# 19973                           0                  0                0
# 19999                           0                  0                0
#
# Education       High School  Master's Degree
# Monthly Income
# 1009                      1                0
# ...

# %%
sns.swarmplot(data=data,x='Age',y='Department',hue='Gender')
# Out:
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 34.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Age', ylabel='Department'>
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\asmaj\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 49.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
